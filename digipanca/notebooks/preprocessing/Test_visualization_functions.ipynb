# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from src.data import PancreasDataset
from src.data.dataset import RAW_DIR
from src.utils.visualization import visualize_sample, visualize_label_mask

# %%
sample_dirs = [os.path.join(RAW_DIR, sd) for sd in os.listdir(RAW_DIR)]
rtum1 = sample_dirs[0]
print(rtum1)
dataset = PancreasDataset([rtum1])
# Out:
# C:\Users\Usuario\TFG\digipanca\data\raw\rtum1
# 📊 Loading dataset... 1 patients found.
# 📊 Dataset loaded with 91 slices.

# %%
visualize_sample(dataset, 28, alpha=0.5, zoom=1.0)

# %%
visualize_label_mask(dataset, 28, 1)
