# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import nibabel as nib
import numpy as np
import torch
os.chdir('C:\\Users\\Usuario\\TFG\\digipanca\\')

# %%
import numpy as np
import matplotlib.pyplot as plt

image = np.load("data/processed/train/images/image_rtum35_0.npy")

# Mostrar las primeras slices
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for i, idx in enumerate([0, 9, 20]):  # Slices clave
    axes[i].imshow(image[:, :, idx], cmap="gray")
    axes[i].set_title(f"Slice {idx}")
plt.show()

# %%
print("Valores únicos en la Slice 0:", np.unique(image[:, :, 58]))
# Out:
# Valores únicos en la Slice 0: [-1024. -1023. -1022. ...  1071.  1082.  1108.]

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 4))
for i, idx in enumerate([0, 5, 10, 15, 20]):  # Slices clave
    axes[i].imshow(image[:, :, idx], cmap="gray")
    axes[i].set_title(f"Slice {idx}")
plt.show()

# %%
print(image.shape)
# Out:
# (512, 512, 64)
